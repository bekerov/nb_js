# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2e47e9da-7dda-4fd2-99dc-d48b91c54525">Loading BokehJS ...</span>
#     </div>

# %%
N = 9
x = np.linspace(-2, 2, N)
y = x**2
sizes = np.linspace(10, 20, N)
xpts = np.array([-.09, -.12, .0, .12, .09])
ypts = np.array([-.1, .02, .1, .02, -.1])
figures = []

# %%
p = figure(title="annular_wedge")
p.annular_wedge(x, y, 10, 20, 0.6, 4.1, color="#8888ee",
    inner_radius_units="screen", outer_radius_units="screen")
figures.append(p)

# %%
p = figure(title="annulus")
p.annulus(x, y, 10, 20, color="#7FC97F",
    inner_radius_units="screen", outer_radius_units = "screen")
figures.append(p)

# %%
show(gridplot(figures, ncols=3, plot_width=200, plot_height=200))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="157722a7-cb34-4bba-af7c-2bfb9de4148e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("157722a7-cb34-4bba-af7c-2bfb9de4148e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("157722a7-cb34-4bba-af7c-2bfb9de4148e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '157722a7-cb34-4bba-af7c-2bfb9de4148e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7fea712f-0947-4665-9c9d-82e04fe96eda":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"AAAAAAAAAMAAAAAAAAD4vwAAAAAAAPC/AAAAAAAA4L8AAAAAAAAAAAAAAAAAAOA/AAAAAAAA8D8AAAAAAAD4PwAAAAAAAABA","dtype":"float64","shape":[9]},"y":{"__ndarray__":"AAAAAAAAEEAAAAAAAAACQAAAAAAAAPA/AAAAAAAA0D8AAAAAAAAAAAAAAAAAANA/AAAAAAAA8D8AAAAAAAACQAAAAAAAABBA","dtype":"float64","shape":[9]}}},"id":"13b888c4-f715-4c93-a4c3-3e995ce0413f","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"098747ef-e4a7-40a2-9ed8-506962fa39fd","type":"BoxAnnotation"},"plot":{"id":"bdb918ef-7092-4267-a84b-587337d8e520","subtype":"Figure","type":"Plot"}},"id":"d530853b-0e7c-4a28-9ee9-e740966286cc","type":"BoxZoomTool"},{"attributes":{},"id":"3ce98777-5b09-4698-a73f-b7b1859129af","type":"BasicTicker"},{"attributes":{"end_angle":{"units":"rad","value":4.1},"fill_color":{"value":"#8888ee"},"inner_radius":{"units":"screen","value":10},"line_color":{"value":"#8888ee"},"outer_radius":{"units":"screen","value":20},"start_angle":{"units":"rad","value":0.6},"x":{"field":"x"},"y":{"field":"y"}},"id":"584e7dcf-9328-4753-a262-7d2255ed3c4a","type":"AnnularWedge"},{"attributes":{"children":[{"id":"ee403ef0-fad2-4f21-8759-9609d73ab597","type":"Row"}]},"id":"842b4a89-de8c-48f7-a7db-f460b521d8f9","type":"Column"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"098747ef-e4a7-40a2-9ed8-506962fa39fd","type":"BoxAnnotation"},{"attributes":{},"id":"0ed7562c-7fa2-44f8-98ef-c75087bce89c","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"AAAAAAAAAMAAAAAAAAD4vwAAAAAAAPC/AAAAAAAA4L8AAAAAAAAAAAAAAAAAAOA/AAAAAAAA8D8AAAAAAAD4PwAAAAAAAABA","dtype":"float64","shape":[9]},"y":{"__ndarray__":"AAAAAAAAEEAAAAAAAAACQAAAAAAAAPA/AAAAAAAA0D8AAAAAAAAAAAAAAAAAANA/AAAAAAAA8D8AAAAAAAACQAAAAAAAABBA","dtype":"float64","shape":[9]}}},"id":"2bde1501-bf4c-43f4-af9b-b22f35032ea7","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"6ad7ef1f-7eae-4fd2-983e-9eed0bc063d1","type":"DataRange1d"},{"attributes":{"plot":{"id":"bdb918ef-7092-4267-a84b-587337d8e520","subtype":"Figure","type":"Plot"},"ticker":{"id":"852b23ba-1d3b-493e-a66c-bfdcd57193bf","type":"BasicTicker"}},"id":"9f7541c2-a35d-48bb-8c44-7188bcfb6590","type":"Grid"},{"attributes":{"formatter":{"id":"ad6e5aa7-538e-4d7c-91df-74a5c3fd501d","type":"BasicTickFormatter"},"plot":{"id":"bdb918ef-7092-4267-a84b-587337d8e520","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc5c88cd-9904-4ea2-8fd1-9180ed3c128f","type":"BasicTicker"}},"id":"2e4784a8-b83c-448a-a550-57197b28a548","type":"LinearAxis"},{"attributes":{},"id":"2f4e4390-7890-4241-94c1-f131a6ae3f03","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"92dcff4c-4803-4485-ad5e-e201793ac754","type":"LinearAxis"}],"left":[{"id":"c864ba13-9117-42d7-bbb7-0ade7be14cba","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"92dcff4c-4803-4485-ad5e-e201793ac754","type":"LinearAxis"},{"id":"0115b95c-a1c9-4811-b09d-ed6e1abe3179","type":"Grid"},{"id":"c864ba13-9117-42d7-bbb7-0ade7be14cba","type":"LinearAxis"},{"id":"05b84745-4666-4e25-89ef-f557956d70b4","type":"Grid"},{"id":"eac9afa5-a115-403f-9c23-855de8ba1fd9","type":"BoxAnnotation"},{"id":"6b2e1bfd-6ea8-474b-bc5d-52f6aa9c724b","type":"GlyphRenderer"}],"title":{"id":"24f3b4dc-ae1b-45de-be7a-474ef1c061b4","type":"Title"},"tool_events":{"id":"bf53d66f-7ad2-4f49-98c1-a6c9150813b7","type":"ToolEvents"},"toolbar":{"id":"856c5f77-94e2-4bab-ab3f-7a4465b7d8c9","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"2a1cb1a5-fbb4-4753-b0c7-e07ac7d65e92","type":"DataRange1d"},"y_range":{"id":"6ad7ef1f-7eae-4fd2-983e-9eed0bc06 ...
